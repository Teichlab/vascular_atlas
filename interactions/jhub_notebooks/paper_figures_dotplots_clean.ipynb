# %% [markdown]
# # ec-smc

# %%
import scanpy as sc
import numpy as np
import pandas as pd
adata = sc.read_h5ad('/home/jovyan/1_FIBROSIS/adata_for_cpdb.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 65964 × 31402
#     obs: 'organ_uni', 'donor', 'kit', 'sorting', 'location', 'age', 'gender', 'dissociation', 'ann_ec_final', 'ann_mural_final', 'ann_final', 'ann_final_2', 'Organ', 'Organ_celltype', 'celltype'
#     var: 'ENSG_id', 'gene_name_33538', 'gene_name_33694', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'rb', 'gene_names_hg_v1.2-0-0-0'

# %%
np.unique(adata.obs['ann_final_2'])
# Out:
# array(['adip_cap_ec', 'aerocyte_ec', 'aorta_ec', 'art_ec_1', 'art_ec_2',
#        'art_smc', 'cap_ec', 'cap_pc', 'cap_pc_endom', 'endocardial_ec',
#        'endometrium_cap_ec', 'glomeruli_ec', 'kidney_art_ec',
#        'kidney_cap_ec', 'large_art_smc', 'myo_cap_ec',
#        'myometrium_cap_ec', 'pericentral_cap_ec', 'periportal_cap_ec',
#        'pul_art_ec', 'pul_cap_ec', 'pul_pc', 'pul_smc', 'pul_tip_cap_ec',
#        'pul_ven_ec', 'remodeling_pv', 'spleen_art_ec', 'ven_ec_1',
#        'ven_ec_2', 'ven_smc', 'ven_smc_pc'], dtype=object)

# %%
adata = adata[adata.obs['ann_final_2'].isin(['art_ec_1', 'art_ec_2', 'art_smc'])]

# %%
adata = adata[adata.obs['organ_uni'].isin(['heart', 'large_intestine', 'small_intestine'])]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 4525 × 31402
#     obs: 'organ_uni', 'donor', 'kit', 'sorting', 'location', 'age', 'gender', 'dissociation', 'ann_ec_final', 'ann_mural_final', 'ann_final', 'ann_final_2', 'Organ', 'Organ_celltype', 'celltype'
#     var: 'ENSG_id', 'gene_name_33538', 'gene_name_33694', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'rb', 'gene_names_hg_v1.2-0-0-0'

# %%
np.unique(adata.obs['Organ_celltype'])
# Out:
# array(['Heart_art_ec_1', 'Heart_art_ec_2', 'Heart_art_smc',
#        'Large_intestine_art_ec_1', 'Large_intestine_art_ec_2',
#        'Large_intestine_art_smc', 'Small_intestine_art_ec_1',
#        'Small_intestine_art_ec_2', 'Small_intestine_art_smc'],
#       dtype=object)

# %%
# Define the desired order of categories
desired_order = ['Heart_art_ec_1','Large_intestine_art_ec_1', 'Small_intestine_art_ec_1', 
                'Heart_art_ec_2',  'Large_intestine_art_ec_2',  'Small_intestine_art_ec_2',
                'Heart_art_smc', 'Large_intestine_art_smc', 'Small_intestine_art_smc']  # Replace with your desired category order

# Convert 'Organ_celltype' to a Categorical with the desired order
adata.obs['Organ_celltype'] = pd.Categorical(adata.obs['Organ_celltype'], categories=desired_order, ordered=True)

# Now, the 'Organ_celltype' categories are reordered as per your desired
# Out:
# /tmp/ipykernel_582/1617862805.py:7: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['Organ_celltype'] = pd.Categorical(adata.obs['Organ_celltype'], categories=desired_order, ordered=True)

# %%
sc.pl.dotplot(adata, ['VEGFA', 'FLT1', 'KDR', 'NRP1'], groupby='Organ_celltype', 
              swap_axes=True, title="VEGFA")
# Out:
# /home/jovyan/my-conda-envs/celltypist/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata, ['RBP1',
    'ALDH1A2','CRABP2', 'RARA', 'RXRA'], groupby='Organ_celltype', 
              swap_axes=True, title="RA")
# Out:
# /home/jovyan/my-conda-envs/celltypist/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
import scanpy as sc
import numpy as np
import pandas as pd
adata = sc.read_h5ad('/home/jovyan/1_FIBROSIS/adata_for_cpdb.h5ad')

# %%
adata = adata[adata.obs['ann_final_2'].isin(['art_ec_1', 'art_ec_2', 'art_smc'])]

# %%
np.unique(adata.obs['organ_uni'])
# Out:
# array(['adipose_tissue', 'bladder', 'decidua', 'heart', 'kidney',
#        'large_intestine', 'large_vessels', 'liver', 'lung', 'lymph_node',
#        'muscle', 'oesophagus', 'pancreas', 'small_intestine', 'spleen',
#        'thymus', 'uterus'], dtype=object)

# %%
adata = adata[adata.obs['organ_uni'].isin(['adipose_tissue', 'heart',
       'large_intestine', 'lung', 'lymph_node',
       'muscle',  'small_intestine'])]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 9753 × 31402
#     obs: 'organ_uni', 'donor', 'kit', 'sorting', 'location', 'age', 'gender', 'dissociation', 'ann_ec_final', 'ann_mural_final', 'ann_final', 'ann_final_2', 'Organ', 'Organ_celltype', 'celltype'
#     var: 'ENSG_id', 'gene_name_33538', 'gene_name_33694', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'rb', 'gene_names_hg_v1.2-0-0-0'

# %%
np.unique(adata.obs['Organ_celltype'])
# Out:
# array(['Adipose_tissue_art_ec_2', 'Adipose_tissue_art_smc',
#        'Heart_art_ec_1', 'Heart_art_ec_2', 'Heart_art_smc',
#        'Large_intestine_art_ec_1', 'Large_intestine_art_ec_2',
#        'Large_intestine_art_smc', 'Lung_art_ec_1', 'Lung_art_ec_2',
#        'Lung_art_smc', 'Lymph_node_art_ec_1', 'Lymph_node_art_ec_2',
#        'Lymph_node_art_smc', 'Muscle_art_ec_1', 'Muscle_art_ec_2',
#        'Muscle_art_smc', 'Small_intestine_art_ec_1',
#        'Small_intestine_art_ec_2', 'Small_intestine_art_smc'],
#       dtype=object)

# %%
adata.obs['Organ_celltype'].value_counts()
# Out:
# Organ_celltype
# Muscle_art_smc              3137
# Heart_art_ec_2              1788
# Heart_art_smc               1413
# Muscle_art_ec_2              516
# Lung_art_smc                 444
# Adipose_tissue_art_smc       381
# Small_intestine_art_smc      362
# Small_intestine_art_ec_1     253
# Large_intestine_art_smc      223
# Lymph_node_art_smc           201
# Heart_art_ec_1               189
# Lymph_node_art_ec_2          185
# Adipose_tissue_art_ec_2      159
# Large_intestine_art_ec_1     125
# Small_intestine_art_ec_2     114
# Lung_art_ec_2                109
# Large_intestine_art_ec_2      58
# Muscle_art_ec_1               35
# Lung_art_ec_1                 33
# Lymph_node_art_ec_1           28
# Name: count, dtype: int64

# %%
# Define the desired order of categories
desired_order = ['Heart_art_ec_1','Large_intestine_art_ec_1', 'Small_intestine_art_ec_1', 
                'Heart_art_ec_2',  'Large_intestine_art_ec_2',  'Small_intestine_art_ec_2',
                 'Adipose_tissue_art_ec_2', 'Muscle_art_ec_2', 'Lung_art_ec_2', 'Lymph_node_art_ec_2',
                'Heart_art_smc', 'Large_intestine_art_smc', 'Small_intestine_art_smc', 
                'Adipose_tissue_art_smc', 'Muscle_art_smc', 'Lung_art_smc', 'Lymph_node_art_smc' ]  # Replace with your desired category order

# Convert 'Organ_celltype' to a Categorical with the desired order
adata.obs['Organ_celltype'] = pd.Categorical(adata.obs['Organ_celltype'], categories=desired_order, ordered=True)

# Now, the 'Organ_celltype' categories are reordered as per your desired
# Out:
# /tmp/ipykernel_582/4286508879.py:9: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['Organ_celltype'] = pd.Categorical(adata.obs['Organ_celltype'], categories=desired_order, ordered=True)

# %%
sc.pl.dotplot(adata, ['NGF', 'SORT1'], groupby='Organ_celltype', 
               title="Beta-nerve growth factor")
# Out:
# /home/jovyan/my-conda-envs/celltypist/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %% [markdown]
# # cap - pc

# %%
import scanpy as sc
adata = sc.read_h5ad('/home/jovyan/1_FIBROSIS/adata_for_cpdb.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 65964 × 31402
#     obs: 'organ_uni', 'donor', 'kit', 'sorting', 'location', 'age', 'gender', 'dissociation', 'ann_ec_final', 'ann_mural_final', 'ann_final', 'ann_final_2', 'Organ', 'Organ_celltype', 'celltype'
#     var: 'ENSG_id', 'gene_name_33538', 'gene_name_33694', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'rb', 'gene_names_hg_v1.2-0-0-0'

# %%
adata = adata[adata.obs['Organ_celltype'].isin(['Heart_myo_cap_ec', 'Lung_pul_cap_ec', 'Heart_cap_pc', 
                                               'Muscle_myo_cap_ec', 'Pancreas_cap_ec', 'Muscle_cap_pc', 
                                               'Uterus_cap_pc_endom', 'Uterus_endometrium_cap_ec', 'Lung_pul_cap_ec', 
                                               'Lung_pul_pc', 'Lung_pul_tip_cap_ec', 'Pancreas_cap_pc', 
                                                'Decidua_cap_pc', 'Decidua_endometrium_cap_ec', 'Thymus_adip_cap_ec',
                                                'Thymus_cap_pc', 'Adipose_tissue_adip_cap_ec', 'Adipose_tissue_cap_pc',
                                                'Lymph_node_adip_cap_ec', 'Lymph_node_cap_pc'
                                               ])]

# %%
import numpy as np
np.unique(adata.obs['Organ_celltype'])
# Out:
# array(['Adipose_tissue_adip_cap_ec', 'Adipose_tissue_cap_pc',
#        'Decidua_cap_pc', 'Decidua_endometrium_cap_ec', 'Heart_cap_pc',
#        'Heart_myo_cap_ec', 'Lung_pul_cap_ec', 'Lung_pul_pc',
#        'Lung_pul_tip_cap_ec', 'Lymph_node_adip_cap_ec',
#        'Lymph_node_cap_pc', 'Muscle_cap_pc', 'Muscle_myo_cap_ec',
#        'Pancreas_cap_ec', 'Pancreas_cap_pc', 'Thymus_adip_cap_ec',
#        'Thymus_cap_pc', 'Uterus_cap_pc_endom',
#        'Uterus_endometrium_cap_ec'], dtype=object)

# %%
import pandas as pd
# Define the desired order of categories
desired_order = ['Heart_myo_cap_ec', 'Muscle_myo_cap_ec','Uterus_endometrium_cap_ec', 'Decidua_endometrium_cap_ec',
                 'Lung_pul_cap_ec', 'Lung_pul_tip_cap_ec', 'Adipose_tissue_adip_cap_ec', 'Thymus_adip_cap_ec', 'Lymph_node_adip_cap_ec', 
                 'Pancreas_cap_ec', 
                'Heart_cap_pc', 'Muscle_cap_pc', 'Uterus_cap_pc_endom', 'Decidua_cap_pc', 'Lung_pul_pc',  'Adipose_tissue_cap_pc', 'Thymus_cap_pc',
                 'Lymph_node_cap_pc',  'Pancreas_cap_pc']  # Replace with your desired category order

# Convert 'Organ_celltype' to a Categorical with the desired order
adata.obs['Organ_celltype'] = pd.Categorical(adata.obs['Organ_celltype'], categories=desired_order, ordered=True)

# Now, the 'Organ_celltype' categories are reordered as per your desired

# %%
sc.pl.dotplot(adata, ['WNT5A', 'SFRP1', 'SFRP4', 'FRZB', 'WNT6','FZD4', 'LRP5', 'LRP6'], groupby='Organ_celltype', 
                  swap_axes=True, title="WNT")
# Out:
# /home/jovyan/my-conda-envs/celltypist/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata, ['PTGES2', 'PTGES3','PTGER1', 'PTGER2', 'PTGER3', 'PTGER4'], groupby='Organ_celltype', 
                  swap_axes=True, title="PTG")
# Out:
# /home/jovyan/my-conda-envs/celltypist/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata, ['HSD17B12', 'SRD5A3', 'AR'], groupby='Organ_celltype', 
                   title="androg")
# Out:
# /home/jovyan/my-conda-envs/celltypist/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)
