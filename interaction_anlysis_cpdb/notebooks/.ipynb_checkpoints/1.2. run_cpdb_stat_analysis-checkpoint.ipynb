# %% [markdown]
# # Use cpdb via jhub notebook

# %%
import pandas as pd
import glob
import os

# %% [markdown]
# # Display database versions

# %%
from IPython.display import HTML, display
from cellphonedb.utils import db_releases_utils

display(HTML(db_releases_utils.get_remote_database_versions_html()['db_releases_html_table']))
# Out:
# <table class="striped"><tr><th style="text-align:center">Version</th><th style="text-align:center">Release date</th></tr><td style="text-align:center"><a class="teal-text" href="https://github.com/ventolab/cellphonedb-data/releases/tag/v5.0.0">v5.0.0</a></td><td style="text-align:center">2023-10-31</td></tr><tr><td style="text-align:center"><a class="teal-text" href="https://github.com/ventolab/cellphonedb-data/releases/tag/v4.1.0">v4.1.0</a></td><td style="text-align:center">2023-03-09</td></tr><tr><tr><tr></table>

# %% [markdown]
# # Define the version and the path to download database

# %%
# -- Version of the databse
cpdb_version = 'v4.1.0'

# -- Path where the input files to generate the database are located
cpdb_target_dir = os.path.join('/nfs/team205/ac65/vasculature/after_annotation/vascular_atlas', cpdb_version)

# %% [markdown]
# # Download database

# %%
from cellphonedb.utils import db_utils

db_utils.download_database(cpdb_target_dir, cpdb_version)
# Out:
# Downloaded cellphonedb.zip into /nfs/team205/ac65/vasculature/after_annotation/vascular_atlas/v4.1.0
# Downloaded complex_input.csv into /nfs/team205/ac65/vasculature/after_annotation/vascular_atlas/v4.1.0
# Downloaded gene_input.csv into /nfs/team205/ac65/vasculature/after_annotation/vascular_atlas/v4.1.0
# Downloaded interaction_input.csv into /nfs/team205/ac65/vasculature/after_annotation/vascular_atlas/v4.1.0
# Downloaded protein_input.csv into /nfs/team205/ac65/vasculature/after_annotation/vascular_atlas/v4.1.0
# Downloaded uniprot_synonyms.tsv into /nfs/team205/ac65/vasculature/after_annotation/vascular_atlas/v4.1.0/sources

# %% [markdown]
# # Run cpdb

# %%
from cellphonedb.src.core.methods import cpdb_statistical_analysis_method

cpdb_statistical_analysis_method.call(
        cpdb_file_path = '/nfs/team205/ac65/vasculature/after_annotation/vascular_atlas/v4.1.0/cellphonedb.zip',
        meta_file_path = '/nfs/team205/ac65/vasculature/after_annotation/annotated_objects/cpdb_in_stat/meta.tsv',
        counts_file_path = '/nfs/team205/ac65/vasculature/after_annotation/annotated_objects/cpdb_in_stat/adata_for_cpdb_log1p.h5ad',
        counts_data = 'hgnc_symbol',
        microenvs_file_path = '/nfs/team205/ac65/vasculature/after_annotation/annotated_objects/cpdb_in_stat/microenvironments.tsv',
        threshold = 0.1,
        output_path = '/nfs/team205/ac65/vasculature/after_annotation/annotated_objects/cpdb_out_stat_log1p/')
# Out:
# Reading user files...
# The following user files were loaded successfully:
# /nfs/team205/ac65/vasculature/after_annotation/annotated_objects/cpdb_in_stat/adata_for_cpdb_log1p.h5ad
# /nfs/team205/ac65/vasculature/after_annotation/annotated_objects/cpdb_in_stat/meta.tsv
# /nfs/team205/ac65/vasculature/after_annotation/annotated_objects/cpdb_in_stat/microenvironments.tsv
# [ ][CORE][18/07/24-11:25:29][INFO] [Cluster Statistical Analysis] Threshold:0.1 Iterations:1000 Debug-seed:-1 Threads:4 Precision:3
# [ ][CORE][18/07/24-11:25:31][INFO] Running Real Analysis
# [ ][CORE][18/07/24-11:25:31][INFO] Limiting cluster combinations using microenvironments
# [ ][CORE][18/07/24-11:25:31][INFO] Running Statistical Analysis
# 100%|██████████| 1000/1000 [17:45<00:00,  1.07s/it]
# [ ][CORE][18/07/24-11:43:17][INFO] Building Pvalues result
# [ ][CORE][18/07/24-11:43:18][INFO] Building results
# ...
